# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Import the API key(s)
from config import geoapify_key

# %%
#read in state center lat and lons
state_centers = pd.read_csv('resources/states_centers.csv')
#read in zip code CSV to retrieve state abbreviations for later access
zip_df = pd.read_csv('resources/us_zips.csv', delimiter=";")
#Drop columns other than Zip Code and State, then sort by State while dropping the original index and replacing it with Official State Name
states_clean = zip_df.loc[:,['Official USPS State Code','Official State Name']].sort_values('Official State Name').drop_duplicates().reset_index(drop=True)
#rename for merge
states_abbrev = states_clean.rename(columns={'Official State Name':'state',
                                            'Official USPS State Code':'state_abbrev'})
#Preview dataframe of state abbrev to full name converting dataframe
merged_states = state_centers.merge(states_abbrev,'inner')
merged_states
#now have a clean df of each states center and abbreviation
# Out:
#                    state  latitude  longitude state_abbrev
# 0                Alabama   32.7794   -86.8287           AL
# 1                 Alaska   64.0685  -152.2782           AK
# 2                Arizona   34.2744  -111.6602           AZ
# 3               Arkansas   34.8938   -92.4426           AR
# 4             California   37.1841  -119.4696           CA
# 5               Colorado   38.9972  -105.5478           CO
# 6            Connecticut   41.6219   -72.7273           CT
# 7               Delaware   38.9896   -75.5050           DE
# 8   District of Columbia   38.9101   -77.0147           DC
# 9                Florida   28.6305   -82.4497           FL
# 10               Georgia   32.6415   -83.4426           GA
# 11                Hawaii   20.2927  -156.3737           HI
# 12                 Idaho   44.3509  -114.6130           ID
# 13              Illinois   40.0417   -89.1965           IL
# 14               Indiana   39.8942   -86.2816           IN
# 15                  Iowa   42.0751   -93.4960           IA
# 16                Kansas   38.4937   -98.3804           KS
# 17              Kentucky   37.5347   -85.3021           KY
# 18             Louisiana   31.0689   -91.9968           LA
# 19                 Maine   45.3695   -69.2428           ME
# 20              Maryland   39.0550   -76.7909           MD
# 21         Massachusetts   42.2596   -71.8083           MA
# 22              Michigan   44.3467   -85.4102           MI
# 23             Minnesota   46.2807   -94.3053           MN
# 24           Mississippi   32.7364   -89.6678           MS
# 25              Missouri   38.3566   -92.4580           MO
# 26               Montana   47.0527  -109.6333           MT
# 27              Nebraska   41.5378   -99.7951           NE
# 28                Nevada   39.3289  -116.6312           NV
# 29         New Hampshire   43.6805   -71.5811           NH
# 30            New Jersey   40.1907   -74.6728           NJ
# 31            New Mexico   34.4071  -106.1126           NM
# 32              New York   42.9538   -75.5268           NY
# 33        North Carolina   35.5557   -79.3877           NC
# 34          North Dakota   47.4501  -100.4659           ND
# 35                  Ohio   40.2862   -82.7937           OH
# 36              Oklahoma   35.5889   -97.4943           OK
# 37                Oregon   43.9336  -120.5583           OR
# 38          Pennsylvania   40.8781   -77.7996           PA
# 39          Rhode Island   41.6762   -71.5562           RI
# 40        South Carolina   33.9169   -80.8964           SC
# 41          South Dakota   44.4443  -100.2263           SD
# 42             Tennessee   35.8580   -86.3505           TN
# 43                 Texas   31.4757   -99.3312           TX
# 44                  Utah   39.3055  -111.6703           UT
# 45               Vermont   44.0687   -72.6658           VT
# 46              Virginia   37.5215   -78.8537           VA
# 47            Washington   47.3826  -120.4472           WA
# 48         West Virginia   38.6409   -80.6227           WV
# 49             Wisconsin   44.6243   -89.9941           WI
# 50               Wyoming   42.9957  -107.5512           WY

# %%
api_sport_list = 'sport,activity.sport_club,commercial.outdoor_and_sport,commercial.outdoor_and_sport.ski,commercial.outdoor_and_sport.diving,commercial.outdoor_and_sport.bicycle,commercial.outdoor_and_sport.golf,building.sport'
base_url = 'https://api.geoapify.com/v2/places'
params={
    #'filter':'circle:-98.35,39.50,4506163'
    #'filter':'circle:-98.350231,39.508968,500000',
    'apiKey': geoapify_key,
    'categories': api_sport_list
}
gym_list = []
for index, row in merged_states.iterrows():
    params['filter'] = 'circle:'+ str(row['longitude']) + ',' + str(row['latitude']) + ',' + str(644542.27)
    response = requests.get(base_url,params).json()
    try:
        list_of_features = response['features']
        gym_list.append(len(list_of_features))
    except:
        gym_list.append(np.nan)
print(gym_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/by/46cpvsvs5_s3jj4cpxc1lf780000gn/T/ipykernel_75954/2174343632.py in <module>
#      10 for index, row in merged_states.iterrows():
#      11     params['filter'] = 'circle:'+ str(row['longitude']) + ',' + str(row['latitude']) + ',' + str(644542.27)
# ---> 12     response = requests.get(base_url,params).json()
#      13     try:
#      14         list_of_features = response['features']
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
api_food_list = 'catering.fast_food'
base_url = 'https://api.geoapify.com/v2/places'
params={
    'apiKey': geoapify_key,
    'categories': api_food_list,
    'limit':500
}
food_list = []
for index, row in merged_states.iterrows():
    params['filter'] = 'circle:'+ str(row['longitude']) + ',' + str(row['latitude']) + ',' + str(644542.27)
    response = requests.get(base_url,params).json()
    print(requests.get(base_url,params).url)
    try:
        list_of_features = response['features']
        food_list.append(len(list_of_features))
    except:
        food_list.append(np.nan)
print(food_list)
# Out:
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-86.8287%2C32.7794%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-152.2782%2C64.0685%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-111.6602%2C34.2744%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-92.4426%2C34.8938%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-119.4696%2C37.1841%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-105.5478%2C38.9972%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-72.7273%2C41.6219%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-75.505%2C38.9896%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-77.0147%2C38.9101%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-82.4497%2C28.6305%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-83.4426%2C32.6415%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-156.3737%2C20.2927%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-114.613%2C44.3509%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-89.1965%2C40.0417%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-86.2816%2C39.8942%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-93.496%2C42.0751%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-98.3804%2C38.4937%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-85.3021%2C37.5347%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-91.9968%2C31.0689%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-69.2428%2C45.3695%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-76.7909%2C39.055%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-71.8083%2C42.2596%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-85.4102%2C44.3467%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-94.3053%2C46.2807%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-89.6678%2C32.7364%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-92.458%2C38.3566%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-109.6333%2C47.0527%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-99.7951%2C41.5378%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-116.6312%2C39.3289%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-71.5811%2C43.6805%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-74.6728%2C40.1907%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-106.1126%2C34.4071%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-75.5268%2C42.9538%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-79.3877%2C35.5557%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-100.4659%2C47.4501%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-82.7937%2C40.2862%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-97.4943%2C35.5889%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-120.5583%2C43.9336%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-77.7996%2C40.8781%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-71.5562%2C41.6762%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-80.8964%2C33.9169%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-100.2263%2C44.4443%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-86.3505%2C35.858%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-99.3312%2C31.4757%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-111.6703%2C39.3055%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-72.6658%2C44.0687%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-78.8537%2C37.5215%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-120.4472%2C47.3826%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-80.6227%2C38.6409%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-89.9941%2C44.6243%2C644542.27
# https://api.geoapify.com/v2/places?apiKey=57bd3b862ffe45f9bc02a5ea81c64fd1&categories=catering.fast_food&limit=500&filter=circle%3A-107.5512%2C42.9957%2C644542.27
# [500, 0, 161, 363, 161, 500, 500, 500, 500, 500, 352, 78, 0, 385, 500, 143, 60, 500, 45, 11, 500, 500, 91, 32, 127, 169, 4, 2, 0, 121, 500, 395, 366, 500, 0, 500, 500, 118, 178, 500, 500, 8, 500, 26, 119, 127, 397, 51, 146, 160, 6]
